# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv("../data/인구밀도_인구주택총조사기준__20220425101410.csv", encoding = "cp949")
data
# Out:
#       행정구역별     2018     2019     2020
# 0        전국    514.4    515.7    516.2
# 1     서울특별시  15983.7  15926.9  15839.0
# 2     부산광역시   4409.8   4379.7   4348.9
# 3     대구광역시   2766.7   2750.3   2728.6
# 4     인천광역시   2761.4   2776.6   2765.1
# 5     광주광역시   2973.2   2972.7   2948.5
# 6     대전광역시   2801.0   2777.5   2758.1
# 7     울산광역시   1083.4   1076.9   1069.0
# 8   세종특별자치시    671.9    727.3    761.3
# 9       경기도   1286.2   1305.0   1325.3
# 10      강원도     90.3     90.3     90.4
# 11     충청북도    218.8    220.0    220.3
# 12     충청남도    265.1    265.4    264.0
# 13     전라북도    225.3    224.0    223.4
# 14     전라남도    145.0    144.8    144.9
# 15     경상북도    140.4    140.2    138.9
# 16     경상남도    317.9    317.6    316.2
# 17      제주도    355.8    359.4    362.6

# %% [markdown]
# ##### Quiz
# - 공공데이터(코로나19 예방접종셑너 현황 자료 가져와서 주소 수정하기

# %%
center = pd.read_csv("../data/공공데이터활용지원센터_코로나19 예방접종센터 현황_20210716.csv", encoding = "cp949")
center
# Out:
#       연번   센터유형                        센터명       운영기관               시설명  \
# 0      1  중앙/권역            코로나19 중앙 예방접종센터    국립중앙의료원        국립중앙의료원 D동
# 1      2  중앙/권역          코로나19 중부권역 예방접종센터  순천향대 천안병원    천안시 실내배드민턴장 1층
# 2      3  중앙/권역          코로나19 호남권역 예방접종센터      조선대병원    조선대학교병원 의성관 5층
# 3      4  중앙/권역          코로나19 영남권역 예방접종센터   양산 부산대병원  양산 부산대병원 기숙사동 1층
# 4      5     지역      코로나19 대구광역시 중구 예방접종센터        NaN   계명대학교 대구동산병원 별관
# ..   ...    ...                        ...        ...               ...
# 279  280     지역  코로나19 충청북도 청주시 흥덕구 예방접종센터        NaN           (舊)흥덕구청
# 280  281     지역       코로나19 경기도 파주시 예방접종센터        NaN            운정행복센터
# 281  282     지역      코로나19 경기도 남양주시 예방접종센터        NaN          화도체육문화센터
# 282  283     지역       코로나19 경기도 시흥시 예방접종센터        NaN          시흥국민체육센터
# 283  284     지역      코로나19 충청남도 당진시 예방접종센터        NaN            국민체육센터
#
#       우편번호                     주소        사무실전화번호
# 0     4562    서울특별시 중구 을지로 39길 29   02-2260-7114
# ...

# %%
center = pd.read_csv("../data/공공데이터활용지원센터_코로나19 예방접종센터 현황_20210716.csv", encoding = "cp949")
df = center
location = []
for word in center["주소"].str.split() :
    location.append(word[0])
    
location2 = []
for word in center["주소"].str.split() :
    location2.append(word[1:-1])
    
location_list = join(location,location2)

center["행정구역"] = location
center["행정구역"].unique()
center["행정구역"] = center["행정구역"].replace('대구시',"대구광역시")
center["행정구역"] = center["행정구역"].replace('부산',"부산광역시")
center["행정구역"] = center["행정구역"].replace('울산시',"울산광역시")
center["행정구역"] = center["행정구역"].replace('충남',"충청남도")
center["행정구역"] = center["행정구역"].replace('전남',"전라남도")
center["행정구역"] = center["행정구역"].replace('경북',"경상북도")
center["행정구역"] = center["행정구역"].replace('경기',"경기도")
center["행정구역"] = center["행정구역"].replace('강원',"강원도")
center["행정구역"] = center["행정구역"].replace('전주시',"전라북도")
center["행정구역"] = center["행정구역"].replace('경남',"경상남도")
center["행정구역"] = center["행정구역"].replace('제주시',"제주특별자치도")


center["주소2"] = center["주소"].copy()
center["주소2"] = center["주소2"].replace('대구시',"대구광역시")
center["주소2"] = center["주소2"].replace('부산',"부산광역시")
center["주소2"] = center["주소2"].replace('울산시',"울산광역시")
center["주소2"] = center["주소2"].replace('충남',"충청남도")
center["주소2"] = center["주소2"].replace('전남',"전라남도")
center["주소2"] = center["주소2"].replace('경북',"경상북도")
center["주소2"] = center["주소2"].replace('경기',"경기도")
center["주소2"] = center["주소2"].replace('강원',"강원도")
center["주소2"] = center["주소2"].replace('전주시',"전라북도 전주시")
center["주소2"] = center["주소2"].replace('경남',"경상남도")
center["주소2"] = center["주소2"].replace('제주시',"제주특별자치도") 
center = center[["연번","센터유형","센터명","운영기관","시설명","우편번호","주소","주소2","행정구역","사무실전화번호"]]

# %%
center
# Out:
#       연번   센터유형                        센터명       운영기관               시설명  \
# 0      1  중앙/권역            코로나19 중앙 예방접종센터    국립중앙의료원        국립중앙의료원 D동
# 1      2  중앙/권역          코로나19 중부권역 예방접종센터  순천향대 천안병원    천안시 실내배드민턴장 1층
# 2      3  중앙/권역          코로나19 호남권역 예방접종센터      조선대병원    조선대학교병원 의성관 5층
# 3      4  중앙/권역          코로나19 영남권역 예방접종센터   양산 부산대병원  양산 부산대병원 기숙사동 1층
# 4      5     지역      코로나19 대구광역시 중구 예방접종센터        NaN   계명대학교 대구동산병원 별관
# ..   ...    ...                        ...        ...               ...
# 279  280     지역  코로나19 충청북도 청주시 흥덕구 예방접종센터        NaN           (舊)흥덕구청
# 280  281     지역       코로나19 경기도 파주시 예방접종센터        NaN            운정행복센터
# 281  282     지역      코로나19 경기도 남양주시 예방접종센터        NaN          화도체육문화센터
# 282  283     지역       코로나19 경기도 시흥시 예방접종센터        NaN          시흥국민체육센터
# 283  284     지역      코로나19 충청남도 당진시 예방접종센터        NaN            국민체육센터
#
#       우편번호                     주소        사무실전화번호   행정구역                    주소2
# ...

# %%
center = pd.read_csv("../data/공공데이터활용지원센터_코로나19 예방접종센터 현황_20210716.csv", encoding = "cp949")
center
location = []
for word in center["주소"].str.split() :
    location.append(word[0])
    
location2 = []
for word in center["주소"].str.split() :
    location2.append(word[1::])

for i in range(len(location)):
    location2[i].insert(0,location[i])
    
location_list = " ".join(location2[0])    
location_list
# center["주소2"] = location2
# center["주소2"] = center["주소2"].replace('대구시',"대구광역시")
# center["주소2"] = center["주소2"].replace('부산',"부산광역시")
# center["주소2"] = center["주소2"].replace('울산시',"울산광역시")
# center["주소2"] = center["주소2"].replace('충남',"충청남도")
# center["주소2"] = center["주소2"].replace('전남',"전라남도")
# center["주소2"] = center["주소2"].replace('경북',"경상북도")
# center["주소2"] = center["주소2"].replace('경기',"경기도")
# center["주소2"] = center["주소2"].replace('강원',"강원도")
# center["주소2"] = center["주소2"].replace('전주시',"전라북도 전주시")
# center["주소2"] = center["주소2"].replace('경남',"경상남도")
# center["주소2"] = center["주소2"].replace('제주시',"제주특별자치도") 
# center = center[["연번","센터유형","센터명","운영기관","시설명","우편번호","주소","주소2","사무실전화번호"]]
# center
# Out:
# '서울특별시 중구 을지로 39길 29'

# %% [markdown]
# #### 주소에 특정 단어가 포함된 데이터 추출

# %%
center.query("주소.str.contains('강원')")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [80], in <cell line: 1>()
# ----> 1 center.query("주소.str.contains('강원')")
#
# File ~\anaconda3\lib\site-packages\pandas\core\frame.py:3341, in DataFrame.query(self, expr, inplace, **kwargs)
#    3339 kwargs["level"] = kwargs.pop("level", 0) + 1
#    3340 kwargs["target"] = None
# -> 3341 res = self.eval(expr, **kwargs)
#    3343 try:
#    3344     result = self.loc[res]
#
# File ~\anaconda3\lib\site-packages\pandas\core\frame.py:3471, in DataFrame.eval(self, expr, inplace, **kwargs)
#    3468     kwargs["target"] = self
#    3469 kwargs["resolvers"] = kwargs.get("resolvers", ()) + tuple(resolvers)
# -> 3471 return _eval(expr, inplace=inplace, **kwargs)
#
# ...

# %% [markdown]
# #### 결측치 검색
# - isnull()
# - isna()

# %%
center[center["사무실전화번호"].isnull()]
# Out:
#    연번   센터유형                센터명       운영기관             시설명   우편번호  \
# 1   2  중앙/권역  코로나19 중부권역 예방접종센터  순천향대 천안병원  천안시 실내배드민턴장 1층  31212
#
#                       주소 사무실전화번호
# 1  충청남도 천안시 동남구 천안대로 357     NaN

# %% [markdown]
# #### 결측값 제거
# - DataFrame.dropna(axis=0, how='any', thresh=None, subset=None, inplace=False)

# %%
df = center.copy()
df.dropna(axis = 0 , how = "any", inplace = True)
df
# Out:
#    연번   센터유형                센터명      운영기관               시설명   우편번호  \
# 0   1  중앙/권역    코로나19 중앙 예방접종센터   국립중앙의료원        국립중앙의료원 D동   4562
# 2   3  중앙/권역  코로나19 호남권역 예방접종센터     조선대병원    조선대학교병원 의성관 5층  61452
# 3   4  중앙/권역  코로나19 영남권역 예방접종센터  양산 부산대병원  양산 부산대병원 기숙사동 1층  50612
#
#                     주소   행정구역       사무실전화번호                  주소2
# 0  서울특별시 중구 을지로 39길 29  서울특별시  02-2260-7114  서울특별시 중구 을지로 39길 29
# 2    광주광역시 동구 필문대로 365  광주광역시  062-220-3739    광주광역시 동구 필문대로 365
# 3  경상남도 양산시 물금읍 금오로 20   경상남도  055-360-6701  경상남도 양산시 물금읍 금오로 20

# %% [markdown]
# #### 결측치 특정값으로 채우기

# %%
df = center.copy()
df["운영기관"].fillna(0,inplace = True)
df
# Out:
#       연번   센터유형                        센터명       운영기관               시설명  \
# 0      1  중앙/권역            코로나19 중앙 예방접종센터    국립중앙의료원        국립중앙의료원 D동
# 1      2  중앙/권역          코로나19 중부권역 예방접종센터  순천향대 천안병원    천안시 실내배드민턴장 1층
# 2      3  중앙/권역          코로나19 호남권역 예방접종센터      조선대병원    조선대학교병원 의성관 5층
# 3      4  중앙/권역          코로나19 영남권역 예방접종센터   양산 부산대병원  양산 부산대병원 기숙사동 1층
# 4      5     지역      코로나19 대구광역시 중구 예방접종센터          0   계명대학교 대구동산병원 별관
# ..   ...    ...                        ...        ...               ...
# 279  280     지역  코로나19 충청북도 청주시 흥덕구 예방접종센터          0           (舊)흥덕구청
# 280  281     지역       코로나19 경기도 파주시 예방접종센터          0            운정행복센터
# 281  282     지역      코로나19 경기도 남양주시 예방접종센터          0          화도체육문화센터
# 282  283     지역       코로나19 경기도 시흥시 예방접종센터          0          시흥국민체육센터
# 283  284     지역      코로나19 충청남도 당진시 예방접종센터          0            국민체육센터
#
#       우편번호                     주소   행정구역        사무실전화번호                    주소2
# ...

# %%
df[df["운영기관"].isna()]
# Out:
# Empty DataFrame
# Columns: [연번, 센터유형, 센터명, 운영기관, 시설명, 우편번호, 주소, 행정구역, 사무실전화번호, 주소2]
# Index: []

# %% [markdown]
# #### 데이터프레임에서 한 행씩 처리하는 방법
# - iterrows

# %%
df = center.copy()
for i,row in df.iterrows():
    print(row)
# Out:
# 연번                           1
# 센터유형                     중앙/권역
# 센터명            코로나19 중앙 예방접종센터
# 운영기관                   국립중앙의료원
# 시설명                 국립중앙의료원 D동
# 우편번호                      4562
# 주소         서울특별시 중구 을지로 39길 29
# 행정구역                     서울특별시
# 사무실전화번호           02-2260-7114
# 주소2        서울특별시 중구 을지로 39길 29
# Name: 0, dtype: object
# 연번                             2
# 센터유형                       중앙/권역
# 센터명            코로나19 중부권역 예방접종센터
# 운영기관                   순천향대 천안병원
# 시설명               천안시 실내배드민턴장 1층
# 우편번호                       31212
# 주소         충청남도 천안시 동남구 천안대로 357
# 행정구역                        충청남도
# 사무실전화번호                      NaN
# 주소2        충청남도 천안시 동남구 천안대로 357
# Name: 1, dtype: object
# 연번                         3
# 센터유형                   중앙/권역
# 센터명        코로나19 호남권역 예방접종센터
# 운영기관                   조선대병원
# 시설명           조선대학교병원 의성관 5층
# 우편번호                   61452
# 주소         광주광역시 동구 필문대로 365
# 행정구역                   광주광역시
# ...

# %%
for i, row in df.iterrows():
    print(f'idx:{i:3}, row : {row["센터명"]}, 주소 : {row["주소"]}')
# Out:
# idx:  0, row : 코로나19 중앙 예방접종센터, 주소 : 서울특별시 중구 을지로 39길 29
# idx:  1, row : 코로나19 중부권역 예방접종센터, 주소 : 충청남도 천안시 동남구 천안대로 357
# idx:  2, row : 코로나19 호남권역 예방접종센터, 주소 : 광주광역시 동구 필문대로 365
# idx:  3, row : 코로나19 영남권역 예방접종센터, 주소 : 경상남도 양산시 물금읍 금오로 20
# idx:  4, row : 코로나19 대구광역시 중구 예방접종센터, 주소 : 대구시 중구 달성로 56
# idx:  5, row : 코로나19 서울특별시 성동구 예방접종센터, 주소 : 서울특별시 성동구 고산자로 270
# idx:  6, row : 코로나19 부산광역시 부산진구 예방접종센터, 주소 : 부산 부산진구 시민공원로 73
# idx:  7, row : 코로나19 인천광역시 연수구 예방접종센터, 주소 : 인천광역시 연수구 경원대로 526
# idx:  8, row : 코로나19 광주광역시 서구 예방접종센터, 주소 : 광주광역시 서구 금화로 278
# idx:  9, row : 코로나19 대전광역시 유성구 예방접종센터, 주소 : 대전광역시 유성구 유성대로 978
# idx: 10, row : 코로나19 울산광역시 중구 예방접종센터, 주소 : 울산시 중구 염포로 85
# idx: 11, row : 코로나19 세종특별자치시 예방접종센터, 주소 : 세종특별자치시 달빛1로 227
# idx: 12, row : 코로나19 경기도 수원시 예방접종센터, 주소 : 경기도 수원시 영통구 월드컵로 206
# idx: 13, row : 코로나19 경기도 고양시 일산동구 예방접종센터, 주소 : 경기도 고양시 일산동구 호수로 595
# idx: 14, row : 코로나19 강원도 원주시 예방접종센터, 주소 : 강원도 원주시 서원대로 279
# ...

# %% [markdown]
# #### 주소 정보 가져오기

# %%
df = center.copy()
str(df["주소"]).split()
# Out:
# ['0',
#  '서울특별시',
#  '중구',
#  '을지로',
#  '39길',
#  '29',
#  '1',
#  '충청남도',
#  '천안시',
#  '동남구',
#  '천안대로',
#  '357',
#  '2',
#  '광주광역시',
#  '동구',
#  '필문대로',
#  '365',
#  '3',
#  '경상남도',
#  '양산시',
#  '물금읍',
#  '금오로',
#  '20',
#  '4',
#  '대구시',
#  '중구',
#  '달성로',
#  '56',
#  '...',
#  '279',
#  '충청북도',
#  '청주시',
#  '흥덕구',
#  '대농로',
#  '88',
#  '280',
#  '경기도',
#  '파주시',
#  '와석순환로',
#  '415',
#  '281',
#  '경기도',
#  '남양주시',
#  '화도읍',
#  '수레로',
#  '1259',
#  '282',
#  '경기도',
#  '시흥시',
#  '하중로',
#  '226',
#  '283',
#  '충청남도',
#  '당진시',
#  '시청1로',
#  '30',
#  'Name:',
#  '주소,',
#  'Length:',
#  '284,',
#  'dtype:',
#  'object']

# %%
df = center.copy()
for arr in df["주소"] :
    print(arr.split()[0])
# Out:
# 서울특별시
# 충청남도
# 광주광역시
# 경상남도
# 대구시
# 서울특별시
# 부산
# 인천광역시
# 광주광역시
# 대전광역시
# 울산시
# 세종특별자치시
# 경기도
# 경기도
# 강원도
# 충청북도
# 충남
# 전주시
# 전남
# 경북
# 경남
# 제주시
# 서울특별시
# 서울특별시
# 서울특별시
# 서울특별시
# 서울특별시
# 서울특별시
# 부산광역시
# 인천광역시
# 광주광역시
# 울산광역시
# 경기도
# 경기도
# 경기도
# 강원도
# 강원도
# 강원도
# 충청북도
# 충청북도
# 충청남도
# 충청남도
# 전라북도
# 전라북도
# 전라북도
# 전라남도
# 전라남도
# 경상남도
# 경상남도
# 서울특별시
# 부산광역시
# 부산광역시
# 인천광역시
# 대구광역시
# 대구광역시
# 울산광역시
# 경기
# 경기
# 경기
# 경기
# 충남
# 전남
# 전남
# 전남
# 전남
# 경북
# 경북
# 경북
# 경북
# 경북
# 서울특별시
# 서울특별시
# 서울특별시
# 서울특별시
# 서울특별시
# 서울특별시
# 서울특별시
# 서울특별시
# 서울특별시
# 서울특별시
# 서울특별시
# 서울특별시
# 서울특별시
# 서울특별시
# 서울특별시
# 서울특별시
# 서울특별시
# 대구광역시
# 대구광역시
# 인천광역시
# 인천광역시
# 광주광역시
# 광주광역시
# 광주광역시
# 대전광역시
# 대전광역시
# 대전광역시
# 대전광역시
# 울산광역시
# 울산광역시
# 경기도
# 경기도
# 경기도
# 경기도
# 경기도
# 경기도
# 경기도
# 경기도
# 경기도
# 경기도
# 경기도
# 경기도
# 경기도
# 경기도
# 경기도
# 경기도
# 경기도
# 강원도
# 강원도
# 강원도
# 강원도
# 강원
# 강원도
# 강원도
# 강원도
# 충청북도
# 충청북도
# 충청북도
# 충청남도
# 충청남도
# 충청남도
# 충청남도
# 충청남도
# 충청남도
# 전라북도
# 충청남도
# 전라북도
# 전라북도
# 전라남도
# 전라남도
# 전라남도
# 전라남도
# 전라남도
# 전라남도
# 전라남도
# ...

# %%
# 파이썬 라이브러리 folium 지도에 표시하는 방법
# 크롬브라우저에서 구글맵 사이트로 가서 숭례문의 경도/위도 좌표 복사하기
'''https://www.google.com/maps!3d37.5599518!4d126.9753037 37.560062343664626, 126.97531442620539'''

import folium
map_osm= folium.Map(location= [37.559978, 126.975291], zoom_start=16)
map_osm.save('../data/map.html')

# 지점 마커로 표시
map_osm2= folium.Map(location= [37.559978, 126.975291], zoom_start=16)
folium.Marker(location = [37.559978, 126.975291],
             popup = "숭례문", icon = folium.Icon(color='red',icon = "star")).add_to(map_osm2)
map_osm2.save('../data/map_marker.html')

# web브라우저로 열기
import webbrowser
import os

# 절대경로 입력해야함.
webbrowser.open("C:/Users/madda/Desktop/4학년2학기/데이터 기초 통계/data/map_marker.html")
# Out:
# True
